# %% [markdown]
# # Scraping PubMed for paper titles and abstracts containing the word "HSPA4"

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

def fetch_pmids_from_page(url):
    """Fetch PMIDs from a single PubMed search results page."""
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    pmids = soup.find_all('span', {'class': 'docsum-pmid'})
    pmid_list = [p.get_text() for p in pmids]
    return pmid_list

def retrieve_abstract(pmid):
    pubmed_url = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"
    response = requests.get(pubmed_url)
    if response.status_code != 200:
        print(f"Failed to retrieve PubMed page for PMID {pmid}")
        return None

    soup = BeautifulSoup(response.content, 'html.parser')
    abstract_elem = soup.find('div', class_='abstract-content selected')
    if abstract_elem is None:
        print(f"Abstract not found for PMID {pmid}")
        return None

    abstract_text = abstract_elem.get_text(separator='\n').strip()
    return abstract_text

def scrape_pubmed_details(pmid):
    url = f'https://pubmed.ncbi.nlm.nih.gov/{pmid}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    title = soup.select('h1.heading-title')[0].text.strip() if soup.select('h1.heading-title') else "Title not found"
    abstract = retrieve_abstract(pmid)
    
    data = {'title': title, 'pmid': pmid, 'url': url, 'abstract': abstract}
    return data

# Initialize variables
all_pmids = []
out = []

# Calculate the number of pages based on the total number of articles (201) and articles per page (10)
total_pages = 201// 10 + (1 if 201 % 10 else 0)  # Adding 1 if there's a remainder to account for the last partial page

for page_number in range(total_pages):
    print(f"Processing page {page_number + 1} of {total_pages}")
    # Construct the URL for the current page
    url = f'https://pubmed.ncbi.nlm.nih.gov/?term=hspa4&page={page_number + 1}'
    
    # Fetch PMIDs from the current page
    pmids_on_page = fetch_pmids_from_page(url)
    all_pmids.extend(pmids_on_page)
    
    # Respectful scraping: pause between requests
    time.sleep(1)

# Scrape details for each PMID
for pmid in all_pmids:
    print(f"Scraping details for PMID: {pmid}")
    details = scrape_pubmed_details(pmid)
    out.append(details)
    
    # Respectful scraping: pause between requests
    time.sleep(1)
# Out:
# Processing page 1 of 21
# Processing page 2 of 21
# Processing page 3 of 21
# Processing page 4 of 21
# Processing page 5 of 21
# Processing page 6 of 21
# Processing page 7 of 21
# Processing page 8 of 21
# Processing page 9 of 21
# Processing page 10 of 21
# Processing page 11 of 21
# Processing page 12 of 21
# Processing page 13 of 21
# Processing page 14 of 21
# Processing page 15 of 21
# Processing page 16 of 21
# Processing page 17 of 21
# Processing page 18 of 21
# Processing page 19 of 21
# Processing page 20 of 21
# Processing page 21 of 21
# Scraping details for PMID: 30643287
# Scraping details for PMID: 38589927
# Scraping details for PMID: 34163243
# Scraping details for PMID: 25732714
# Abstract not found for PMID 25732714
# Scraping details for PMID: 34754620
# Scraping details for PMID: 37339521
# Scraping details for PMID: 35628491
# Scraping details for PMID: 35158021
# Scraping details for PMID: 23980576
# Scraping details for PMID: 21487003
# Scraping details for PMID: 22884543
# Scraping details for PMID: 12005543
# Scraping details for PMID: 27129500
# Scraping details for PMID: 37565223
# Scraping details for PMID: 36185081
# Scraping details for PMID: 38305786
# Scraping details for PMID: 38125299
# Scraping details for PMID: 21208456
# Scraping details for PMID: 25437815
# Scraping details for PMID: 25798051
# Scraping details for PMID: 38292659
# Scraping details for PMID: 37942135
# Scraping details for PMID: 25655005
# Scraping details for PMID: 37086043
# Scraping details for PMID: 38266641
# Scraping details for PMID: 34059060
# Scraping details for PMID: 35568953
# Scraping details for PMID: 31900829
# Scraping details for PMID: 37203095
# Scraping details for PMID: 36303457
# Scraping details for PMID: 36269594
# Scraping details for PMID: 25761903
# Scraping details for PMID: 34005840
# Scraping details for PMID: 36292719
# Scraping details for PMID: 34569543
# Scraping details for PMID: 35937592
# Scraping details for PMID: 36167183
# Scraping details for PMID: 35767179
# Scraping details for PMID: 33438283
# Scraping details for PMID: 36138806
# Scraping details for PMID: 32840700
# Scraping details for PMID: 27930406
# Scraping details for PMID: 34745496
# Scraping details for PMID: 36833281
# Scraping details for PMID: 25379943
# Scraping details for PMID: 34235869
# Scraping details for PMID: 32191631
# Scraping details for PMID: 37761919
# Scraping details for PMID: 34278961
# Scraping details for PMID: 34089287
# Scraping details for PMID: 34685777
# Scraping details for PMID: 32853412
# Scraping details for PMID: 35391795
# Scraping details for PMID: 36295788
# Scraping details for PMID: 26755347
# Scraping details for PMID: 38073191
# Scraping details for PMID: 27122963
# Scraping details for PMID: 37298337
# Scraping details for PMID: 24862711
# Scraping details for PMID: 17913078
# Scraping details for PMID: 38945802
# Scraping details for PMID: 37058032
# Scraping details for PMID: 31951614
# Scraping details for PMID: 33896033
# Scraping details for PMID: 33747278
# Scraping details for PMID: 30521813
# Scraping details for PMID: 35891953
# Scraping details for PMID: 38847172
# Scraping details for PMID: 32284329
# Scraping details for PMID: 31182775
# Scraping details for PMID: 34765552
# Scraping details for PMID: 33790969
# Scraping details for PMID: 32011160
# Scraping details for PMID: 25879409
# Scraping details for PMID: 33726698
# Scraping details for PMID: 36312597
# Scraping details for PMID: 35758003
# Scraping details for PMID: 36497125
# Scraping details for PMID: 35233217
# Scraping details for PMID: 36918797
# Scraping details for PMID: 37370521
# Scraping details for PMID: 24718440
# Scraping details for PMID: 34421625
# Scraping details for PMID: 37147328
# Scraping details for PMID: 36979766
# Scraping details for PMID: 32523426
# Scraping details for PMID: 21557452
# Scraping details for PMID: 35442158
# Scraping details for PMID: 31814876
# Scraping details for PMID: 37200358
# Scraping details for PMID: 34479169
# Scraping details for PMID: 16364315
# Scraping details for PMID: 29393436
# Scraping details for PMID: 30500420
# Scraping details for PMID: 37201074
# Scraping details for PMID: 34441954
# Scraping details for PMID: 9395504
# Scraping details for PMID: 24499940
# Scraping details for PMID: 33395399
# Scraping details for PMID: 29428101
# Scraping details for PMID: 36248807
# Scraping details for PMID: 38597327
# Scraping details for PMID: 31893436
# Scraping details for PMID: 29399337
# Scraping details for PMID: 35053185
# Scraping details for PMID: 35056751
# Scraping details for PMID: 35619939
# Scraping details for PMID: 36304495
# Scraping details for PMID: 35292026
# Scraping details for PMID: 21951291
# Scraping details for PMID: 30246258
# Scraping details for PMID: 36776308
# Scraping details for PMID: 30930989
# Scraping details for PMID: 32793473
# Scraping details for PMID: 33639852
# Scraping details for PMID: 35864646
# Scraping details for PMID: 35676653
# Scraping details for PMID: 11237751
# Scraping details for PMID: 37047376
# Scraping details for PMID: 38001817
# Scraping details for PMID: 14987991
# Scraping details for PMID: 26923191
# Scraping details for PMID: 32046932
# Scraping details for PMID: 24660549
# Scraping details for PMID: 33614243
# Scraping details for PMID: 23985558
# Scraping details for PMID: 33806355
# Scraping details for PMID: 27567034
# Scraping details for PMID: 37488801
# Scraping details for PMID: 29528137
# Scraping details for PMID: 17395733
# Scraping details for PMID: 26808319
# Scraping details for PMID: 33126129
# Scraping details for PMID: 24012954
# Scraping details for PMID: 30517152
# Scraping details for PMID: 15897011
# Scraping details for PMID: 19088066
# Scraping details for PMID: 18503584
# Scraping details for PMID: 38476923
# Scraping details for PMID: 32848724
# Scraping details for PMID: 26057247
# Scraping details for PMID: 23315814
# Scraping details for PMID: 33391356
# Scraping details for PMID: 30728947
# Scraping details for PMID: 30891079
# Scraping details for PMID: 27504120
# Scraping details for PMID: 26075067
# Scraping details for PMID: 9108202
# Scraping details for PMID: 20096881
# Scraping details for PMID: 22018955
# Scraping details for PMID: 27908666
# Scraping details for PMID: 16923965
# Scraping details for PMID: 19095035
# Scraping details for PMID: 30521791
# Scraping details for PMID: 11435793
# Scraping details for PMID: 23737532
# Scraping details for PMID: 32221746
# Scraping details for PMID: 26027945
# Scraping details for PMID: 24449167
# Scraping details for PMID: 29100048
# Scraping details for PMID: 31280524
# Scraping details for PMID: 22451153
# Scraping details for PMID: 11522319
# Scraping details for PMID: 27253232
# Scraping details for PMID: 10928558
# Scraping details for PMID: 37653627
# Scraping details for PMID: 21377399
# Scraping details for PMID: 32905537
# Scraping details for PMID: 21297950
# Scraping details for PMID: 32375686
# Scraping details for PMID: 24156634
# Scraping details for PMID: 10566957
# Scraping details for PMID: 31988005
# Scraping details for PMID: 23940031
# Scraping details for PMID: 20433912
# Scraping details for PMID: 17588478
# Scraping details for PMID: 23018186
# Scraping details for PMID: 21914784
# Scraping details for PMID: 10524232
# Scraping details for PMID: 26862520
# Scraping details for PMID: 18601936
# Scraping details for PMID: 18178852
# Scraping details for PMID: 26552463
# Scraping details for PMID: 38322303
# Scraping details for PMID: 21725599
# Scraping details for PMID: 27483141
# Scraping details for PMID: 20198334
# Scraping details for PMID: 25600910
# Scraping details for PMID: 24412164
# Scraping details for PMID: 31640949
# Scraping details for PMID: 11567777
# Scraping details for PMID: 26122279
# Scraping details for PMID: 16790501
# Scraping details for PMID: 10707369
# Scraping details for PMID: 17934269
# Scraping details for PMID: 10098860
# Scraping details for PMID: 11750909
# Scraping details for PMID: 10861836
# Scraping details for PMID: 8074706
# Scraping details for PMID: 16002990
# Scraping details for PMID: 10087208
# Abstract not found for PMID 10087208

# %%
from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# save the results to a CSV file with the current time stamp
filename = f"zero_shot_classification_results_{current_time}.csv"

# Convert to DataFrame
df = pd.DataFrame(out)

# Save to Excel
df.to_csv('pubmed_scraped_data_hspa4.csv', index=False)

df.head()
# Out:
#                                                title      pmid  \
# 0  Tumor-educated B cells selectively promote bre...  30643287
# 1  HSPA4 upregulation induces immune evasion via ...  38589927
# 2  HSPA4 Knockdown Retarded Progression and Devel...  34163243
# 3  HSPA4, the "Evil Chaperone" of the HSP Family,...  25732714
# 4  Significant correlation between HSPA4 and prog...  34754620
#
#                                         url  \
# 0  https://pubmed.ncbi.nlm.nih.gov/30643287
# 1  https://pubmed.ncbi.nlm.nih.gov/38589927
# 2  https://pubmed.ncbi.nlm.nih.gov/34163243
# 3  https://pubmed.ncbi.nlm.nih.gov/25732714
# 4  https://pubmed.ncbi.nlm.nih.gov/34754620
#
#                                             abstract
# 0  Primary tumors may create the premetastatic ni...
# 1  Introduction:\n        \n\n      \n      Gastr...
# 2  Purpose:\n        \n\n      \n      Colorectal...
# 3                                               None
# 4  Background:\n        \n\n      \n      Hepatoc...
# (201, 4)
